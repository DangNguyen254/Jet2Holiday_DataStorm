# %%
import pandas as pd
import os
print("Current working directory:", os.getcwd())
print("\nFiles in current directory:", os.listdir('.'))
# Out:
# Current working directory: d:\Code\Jet2Holiday_DataStorm\sales-forecasting-platform\notebooks
#
# Files in current directory: ['Datastorm.ipynb', 'data_visualization.ipynb']

# %%
# Read the first few rows of the parquet file
parent_dir = os.path.dirname(os.getcwd())
df = pd.read_parquet(os.path.join(parent_dir, "data/processed/train_features.parquet"))
# Print column names and first few rows
print(df['date'].head())
print("\nColumn names:")
print("-" * 50)
print(df.columns.tolist())

print("\nFirst 5 rows:")
print("-" * 50)
print(df.head().to_string())

print("\nData types:")
print("-" * 50)
print(df.dtypes)
# Out:
# 0   2024-03-28
# 1   2024-03-28
# 2   2024-03-28
# 3   2024-03-28
# 4   2024-03-28
# Name: date, dtype: datetime64[ns]
#
# Column names:
# --------------------------------------------------
# ['date', 'sale_amount', 'discount', 'precpt', 'avg_temperature', 'avg_humidity', 'avg_wind_level', 'is_weekend', 'stockout_hours_count', 'is_any_stockout', 'stockout_ratio', 'current_hour_stock', 'stockout_lag_1', 'stockout_lag_24', 'stockout_lag_168', 'has_discount', 'activity_days_rolling_7d', 'discount_lag_24h', 'discount_lag_168h', 'sale_amount_lag_1', 'sale_amount_lag_7', 'sale_amount_lag_14', 'sale_amount_lag_28', 'sale_amount_rolling_3_mean', 'sale_amount_rolling_3_std', 'sale_amount_rolling_7_mean', 'sale_amount_rolling_7_std', 'sale_amount_rolling_14_mean', 'sale_amount_rolling_14_std', 'sale_amount_rolling_28_mean', 'sale_amount_rolling_28_std', 'first_category_id_avg_sales', 'first_category_id_total_sales', 'second_category_id_avg_sales', 'second_category_id_total_sales', 'third_category_id_avg_sales', 'third_category_id_total_sales', 'store_avg_sales', 'store_total_sales', 'temperature_category_0', 'temperature_category_1', 'temperature_category_2', 'precipitation_category_0', 'precipitation_category_1', 'precipitation_category_2', 'humidity_category_0', 'humidity_category_1', 'humidity_category_2', 'wind_category_0', 'wind_category_1']
#
# First 5 rows:
# --------------------------------------------------
#         date  sale_amount  discount  precpt  avg_temperature  avg_humidity  avg_wind_level  is_weekend  stockout_hours_count  is_any_stockout  stockout_ratio  current_hour_stock  stockout_lag_1  stockout_lag_24  stockout_lag_168  has_discount  activity_days_rolling_7d  discount_lag_24h  discount_lag_168h  sale_amount_lag_1  sale_amount_lag_7  sale_amount_lag_14  sale_amount_lag_28  sale_amount_rolling_3_mean  sale_amount_rolling_3_std  sale_amount_rolling_7_mean  sale_amount_rolling_7_std  sale_amount_rolling_14_mean  sale_amount_rolling_14_std  sale_amount_rolling_28_mean  sale_amount_rolling_28_std  first_category_id_avg_sales  first_category_id_total_sales  second_category_id_avg_sales  second_category_id_total_sales  third_category_id_avg_sales  third_category_id_total_sales  store_avg_sales  store_total_sales  temperature_category_0  temperature_category_1  temperature_category_2  precipitation_category_0  precipitation_category_1  precipitation_category_2  humidity_category_0  humidity_category_1  humidity_category_2  wind_category_0  wind_category_1
# 0 2024-03-28          0.5     0.882  1.6999            15.48         73.54            1.97       False                     6                1        0.250000                   1             NaN              NaN               NaN             1                       1.0               NaN                NaN                NaN                NaN                 NaN                 NaN                         NaN                        NaN                         NaN                        NaN                          NaN                         NaN                          NaN                         NaN                     0.747197                        2612.20                      0.533333                          683.20                     0.617985                         484.50         0.693378              51.31                   False                    True                   False                     False                      True                     False                 True                False                False             True            False
# 1 2024-03-28          0.3     1.000  1.7000            15.72         73.51            1.51       False                    17                1        0.708333                   1             NaN              NaN               NaN             1                       0.0               NaN                NaN                0.4                0.2                 0.5                 0.0                         NaN                        NaN                         NaN                        NaN                          NaN                         NaN                          NaN                         NaN                     0.585151                        4199.63                      0.564472                         2538.43                     0.526126                         434.58         0.597867              44.84                   False                    True                   False                     False                      True                     False                 True                False                False             True            False
# 2 2024-03-28          0.9     1.000  3.5917            16.07         81.91            1.54       False                    24                1        1.000000                   1             NaN              NaN               NaN             1                       0.0               NaN                NaN                0.3                0.0                 0.3                 1.0                    0.566667                   0.305505                         NaN                        NaN                          NaN                         NaN                          NaN                         NaN                     0.891831                        9710.26                      0.625396                         1554.11                     0.757818                         982.89         0.750109              69.01                   False                    True                   False                     False                      True                     False                 True                False                False             True            False
# 3 2024-03-28          0.4     0.804  1.7000            15.72         73.51            1.51       False                     7                1        0.291667                   1             NaN              NaN               NaN             1                       1.0               NaN                NaN                0.9                0.5                 0.9                 0.8                    0.533333                   0.321455                         NaN                        NaN                          NaN                         NaN                          NaN                         NaN                     0.585151                        4199.63                      0.649676                         1484.51                     0.516803                         366.93         0.597867              44.84                   False                    True                   False                     False                      True                     False                 True                False                False             True            False
# 4 2024-03-28          0.4     0.863  1.7000            15.72         73.51            1.51       False                     9                1        0.375000                   1             NaN              NaN               NaN             1                       1.0               NaN                NaN                0.4                0.2                 0.7                 1.7                    0.566667                   0.288675                         NaN                        NaN                          NaN                         NaN                          NaN                         NaN                     0.585151                        4199.63                      0.564472                         2538.43                     0.602804                         827.65         0.597867              44.84                   False                    True                   False                     False                      True                     False                 True                False                False             True            False
#
# Data types:
# --------------------------------------------------
# date                              datetime64[ns]
# sale_amount                              float64
# discount                                 float64
# precpt                                   float64
# avg_temperature                          float64
# avg_humidity                             float64
# avg_wind_level                           float64
# is_weekend                                  bool
# stockout_hours_count                       int64
# is_any_stockout                            int64
# stockout_ratio                           float64
# current_hour_stock                         int64
# stockout_lag_1                           float64
# stockout_lag_24                          float64
# stockout_lag_168                         float64
# has_discount                               int64
# activity_days_rolling_7d                 float64
# discount_lag_24h                         float64
# discount_lag_168h                        float64
# sale_amount_lag_1                        float64
# sale_amount_lag_7                        float64
# sale_amount_lag_14                       float64
# sale_amount_lag_28                       float64
# sale_amount_rolling_3_mean               float64
# sale_amount_rolling_3_std                float64
# sale_amount_rolling_7_mean               float64
# sale_amount_rolling_7_std                float64
# sale_amount_rolling_14_mean              float64
# sale_amount_rolling_14_std               float64
# sale_amount_rolling_28_mean              float64
# sale_amount_rolling_28_std               float64
# first_category_id_avg_sales              float64
# first_category_id_total_sales            float64
# second_category_id_avg_sales             float64
# second_category_id_total_sales           float64
# third_category_id_avg_sales              float64
# third_category_id_total_sales            float64
# store_avg_sales                          float64
# store_total_sales                        float64
# temperature_category_0                      bool
# temperature_category_1                      bool
# temperature_category_2                      bool
# precipitation_category_0                    bool
# precipitation_category_1                    bool
# precipitation_category_2                    bool
# humidity_category_0                         bool
# humidity_category_1                         bool
# humidity_category_2                         bool
# wind_category_0                             bool
# wind_category_1                             bool
# dtype: object

# %%
df = pd.read_parquet(os.path.join(parent_dir, "data/processed/eval_features.parquet"))

# Print column names and first few rows
print("\nColumn names:")
print("-" * 50)
print(df.columns.tolist())

print("\nFirst 5 rows:")
print("-" * 50)
print(df.head().to_string())

print("\nData types:")
print("-" * 50)
print(df.dtypes)
# Out:
# Column names:
# --------------------------------------------------
# ['date', 'sale_amount', 'discount', 'precpt', 'avg_temperature', 'avg_humidity', 'avg_wind_level', 'is_weekend', 'stockout_hours_count', 'is_any_stockout', 'stockout_ratio', 'current_hour_stock', 'stockout_lag_1', 'stockout_lag_24', 'stockout_lag_168', 'has_discount', 'activity_days_rolling_7d', 'discount_lag_24h', 'discount_lag_168h', 'sale_amount_lag_1', 'sale_amount_lag_7', 'sale_amount_lag_14', 'sale_amount_lag_28', 'sale_amount_rolling_3_mean', 'sale_amount_rolling_3_std', 'sale_amount_rolling_7_mean', 'sale_amount_rolling_7_std', 'sale_amount_rolling_14_mean', 'sale_amount_rolling_14_std', 'sale_amount_rolling_28_mean', 'sale_amount_rolling_28_std', 'first_category_id_avg_sales', 'first_category_id_total_sales', 'second_category_id_avg_sales', 'second_category_id_total_sales', 'third_category_id_avg_sales', 'third_category_id_total_sales', 'store_avg_sales', 'store_total_sales', 'temperature_category_0', 'temperature_category_1', 'precipitation_category_0', 'precipitation_category_1', 'humidity_category_0', 'humidity_category_1', 'wind_category_0', 'wind_category_1']
#
# First 5 rows:
# --------------------------------------------------
#         date  sale_amount  discount  precpt  avg_temperature  avg_humidity  avg_wind_level  is_weekend  stockout_hours_count  is_any_stockout  stockout_ratio  current_hour_stock  stockout_lag_1  stockout_lag_24  stockout_lag_168  has_discount  activity_days_rolling_7d  discount_lag_24h  discount_lag_168h  sale_amount_lag_1  sale_amount_lag_7  sale_amount_lag_14  sale_amount_lag_28  sale_amount_rolling_3_mean  sale_amount_rolling_3_std  sale_amount_rolling_7_mean  sale_amount_rolling_7_std  sale_amount_rolling_14_mean  sale_amount_rolling_14_std  sale_amount_rolling_28_mean  sale_amount_rolling_28_std  first_category_id_avg_sales  first_category_id_total_sales  second_category_id_avg_sales  second_category_id_total_sales  third_category_id_avg_sales  third_category_id_total_sales  store_avg_sales  store_total_sales  temperature_category_0  temperature_category_1  precipitation_category_0  precipitation_category_1  humidity_category_0  humidity_category_1  wind_category_0  wind_category_1
# 0 2024-06-26          0.0  0.949947  8.8076            27.42         81.70            1.55       False                    24                1        1.000000                   1             NaN              NaN               NaN             1                       0.0               NaN                NaN                NaN                NaN                 NaN                 NaN                         NaN                        NaN                         NaN                        NaN                          NaN                         NaN                          NaN                         NaN                     1.329205                       4646.900                      1.067760                         1367.80                     0.471046                         369.30         1.098108              81.26                   False                    True                      True                     False                 True                False             True            False
# 1 2024-06-26          1.4  0.652000  5.9439            28.79         83.63            2.27       False                     9                1        0.375000                   1             NaN              NaN               NaN             1                       1.0               NaN                NaN                0.3                0.2                 0.3                0.50                         NaN                        NaN                         NaN                        NaN                          NaN                         NaN                          NaN                         NaN                     1.626930                       9001.803                      1.582019                         1990.18                     1.952039                        1091.19         1.186207              68.80                   False                    True                      True                     False                 True                False            False             True
# 2 2024-06-26          1.1  0.800000  8.5911            27.26         81.33            1.34       False                    18                1        0.750000                   1             NaN              NaN               NaN             1                       1.0               NaN                NaN                1.4                0.7                 0.6                0.88                    0.833333                   0.737111                         NaN                        NaN                          NaN                         NaN                          NaN                         NaN                     1.305128                      14210.230                      1.428937                        12007.36                     1.098166                        1005.92         1.158491              61.40                   False                    True                      True                     False                 True                False             True            False
# 3 2024-06-26          1.4  1.000000  5.9439            28.79         83.63            2.27       False                    22                1        0.916667                   1             NaN              NaN               NaN             1                       0.0               NaN                NaN                1.1                1.4                 0.6                4.70                    1.300000                   0.173205                         NaN                        NaN                          NaN                         NaN                          NaN                         NaN                     1.305128                      14210.230                      1.428937                        12007.36                     1.078098                         725.56         1.186207              68.80                   False                    True                      True                     False                 True                False            False             True
# 4 2024-06-26          0.5  1.000000  5.7912            27.68         80.43            1.66       False                    24                1        1.000000                   1             NaN              NaN               NaN             1                       0.0               NaN                NaN                1.4                0.1                 0.1                0.50                    1.000000                   0.458258                         NaN                        NaN                          NaN                         NaN                          NaN                         NaN                     1.305128                      14210.230                      1.428937                        12007.36                     1.098166                        1005.92         1.515111              68.18                   False                    True                      True                     False                 True                False             True            False
#
# Data types:
# --------------------------------------------------
# date                              datetime64[ns]
# sale_amount                              float64
# discount                                 float64
# precpt                                   float64
# avg_temperature                          float64
# avg_humidity                             float64
# avg_wind_level                           float64
# is_weekend                                  bool
# stockout_hours_count                       int64
# is_any_stockout                            int64
# stockout_ratio                           float64
# current_hour_stock                         int64
# stockout_lag_1                           float64
# stockout_lag_24                          float64
# stockout_lag_168                         float64
# has_discount                               int64
# activity_days_rolling_7d                 float64
# discount_lag_24h                         float64
# discount_lag_168h                        float64
# sale_amount_lag_1                        float64
# sale_amount_lag_7                        float64
# sale_amount_lag_14                       float64
# sale_amount_lag_28                       float64
# sale_amount_rolling_3_mean               float64
# sale_amount_rolling_3_std                float64
# sale_amount_rolling_7_mean               float64
# sale_amount_rolling_7_std                float64
# sale_amount_rolling_14_mean              float64
# sale_amount_rolling_14_std               float64
# sale_amount_rolling_28_mean              float64
# sale_amount_rolling_28_std               float64
# first_category_id_avg_sales              float64
# first_category_id_total_sales            float64
# second_category_id_avg_sales             float64
# second_category_id_total_sales           float64
# third_category_id_avg_sales              float64
# third_category_id_total_sales            float64
# store_avg_sales                          float64
# store_total_sales                        float64
# temperature_category_0                      bool
# temperature_category_1                      bool
# precipitation_category_0                    bool
# precipitation_category_1                    bool
# humidity_category_0                         bool
# humidity_category_1                         bool
# wind_category_0                             bool
# wind_category_1                             bool
# dtype: object
